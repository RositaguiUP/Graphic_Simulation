# %%
var1= "This is the content of a variable"
print(f"""This is how you use f strings for embedded text and content display.
For example, if i want to display the content of my variable i can just use: {var1}""")
myVall=3
myVal=4
print(f"{myVall} + {myVal} = {myVall+ myVal}")
# Out:
# This is how you use f strings for embedded text and content display.
# For example, if i want to display the content of my variable i can just use: This is the content of a variable
# 3 + 4 = 7

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./misc_files/deeplearning.mplstyle')

# %%
x_train = np.array([1.0,2.0])
y_train = np.array([300.0,500.0])
print(f"x_train:{x_train}")
print(f"y_train:{y_train}")
# Out:
# x_train:[1. 2.]
# y_train:[300. 500.]

# %%
m = x_train.shape[0] # tambien se puede usar m = len(x_train)
print(f"This data set has {m} entries")
# Out:
# This data set has 2 entries

# %% [markdown]
# In this next seccion we are going to define the linear regression function that we will use to evaluate my model.
#
# The formula is: y_i = w_1x_i + b

# %%
w= 100
b= 100
i =0
x_i= x_train[i]
y_i= y_train[i]
print(f"({x_i},{y_i})")
# Out:
# (2104,399900)

# %%
def compute_model_output(x, w, b):
  m = x.shape[0]
  f_wb = np.zeros(m)
  for i in range(m):
    f_wb[i] = w * x[i] + b
  return f_wb

# %%
f_wb = compute_model_output(x_train, w, b)
plt.scatter(x_train, y_train, marker='x', c='g', label='Actual Values')
plt.plot(x_train, f_wb, marker='o', c='r', label='The model prediction')
plt.title("HOUSING PRICES")
plt.ylabel("Price in USD")
plt.xlabel("Size in sq. ft.")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
yr_i = w * x_i + b
print(f"Expected outcome: {yr_i}, real value: {y_i}")
# Out:
# Expected outcome: 210500, real value: 399900

# %%
from os import listxattr
filepath='./houses.csv'

f = open(filepath)
raw = f.read()
#print(raw)
lista = list()
lista = raw
#listas = list(map(int,lista))  


print(lista)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from os import listxattr
#       2 filepath='./houses.csv'
#       4 f = open(filepath)
#
# ImportError: cannot import name 'listxattr' from 'os' (d:\rfmrm\AppData\Local\Programs\Python\Python3 10\lib\os.py)

# %%
x_train = np.array([2104.0, 1600.0, 2400.0, 1416.0, 3000.0, 1985.0, 1534.0, 1427.0, 1380.0, 1494.0, 1940.0, 2000.0, 1890.0, 4478.0, 1268.0, 2300.0, 1320.0, 1236.0, 2609.0, 3031.0, 1767.0, 1888.0, 1604.0, 1962.0, 3890.0, 1100.0, 1458.0, 2526.0, 2200.0, 2637.0, 1839.0, 1000.0, 2040.0, 3137.0, 1811.0, 1437.0, 1239.0, 2132.0, 4215.0, 2162.0, 1664.0, 2238.0, 2567.0, 1200.0, 852.0, 1852.0, 1203.0])
y_train = np.array([399900.0, 329900.0, 369000.0, 232000.0, 539900.0, 299900.0, 314900.0, 198999.0, 212000.0, 242500.0, 239999.0, 347000.0, 329999.0, 699900.0, 259900.0, 449900.0, 299900.0, 199900.0, 499998.0, 599000.0, 252900.0, 255000.0, 242900.0, 259900.0, 573900.0, 249900.0, 464500.0, 469000.0, 475000.0, 299900.0, 349900.0, 169900.0, 314900.0, 579900.0, 285900.0, 249900.0, 229900.0, 345000.0, 549000.0, 287000.0, 368500.0, 329900.0, 314000.0, 299000.0, 179900.0, 299900.0, 239500])
#print(f"x_train:{x_train}")
#print(f"y_train:{y_train}")
#--------------------------------------------------
m = x_train.shape[0]
print(f"This data set has {m} entries")
#--------------------------------------------------
w= 100
b= 100
i =0
x_i= x_train[i]
y_i= y_train[i]
print(f"The linear regression function to evaluate my model ({x_i},{y_i})")
#--------------------------------------------------
def compute_model_output(x, w, b):
  m = x.shape[0]
  f_wb = np.zeros(m)
  for i in range(m):
    f_wb[i] = w * x[i] + b
  return f_wb
#--------------------------------------------------
f_wb = compute_model_output(x_train, w, b)
plt.scatter(x_train, y_train, marker='x', c='g', label='Actual Values')
plt.plot(x_train, f_wb, marker='o', c='r', label='The model prediction')
plt.title("HOUSING PRICES")
plt.ylabel("Price in USD")
plt.xlabel("Size in sq. ft.")
plt.show
#--------------------------------------------------
yr_i = w * x_i + b
print(f"Expected outcome: {yr_i}, real value: {y_i}")
# Out:
# This data set has 47 entries
# The linear regression function to evaluate my model (2104.0,399900.0)
# Expected outcome: 210500.0, real value: 399900.0

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./misc_files/deeplearning.mplstyle')
import pandas as pd

# %%
import pandas as pd
my_data = pd.read_csv("./houses.csv")
my_data.head()
# Out:
#    Size  Rooms   Price
# 0  2104      3  399900
# 1  1600      3  329900
# 2  2400      3  369000
# 3  1416      2  232000
# 4  3000      4  539900

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Size    47 non-null     int64
#  1   Rooms   47 non-null     int64
#  2   Prices  47 non-null     int64
# dtypes: int64(3)
# memory usage: 1.2 KB

# %%
x_train = my_data['Size'].values
y_train = my_data['Price'].values

# %%
plt.scatter(x_train, y_train, marker='x', c='g')
plt.title("HOUSING PRICES")
plt.ylabel("Price in USD")
plt.xlabel("Size in sq. ft.")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
f_wb = compute_model_output(x_train, w, b)
plt.scatter(x_train, y_train, marker='x', c='g', label='Actual Values')
plt.plot(x_train, f_wb, marker='o', c='r', label='The model prediction')
plt.title("HOUSING PRICES")
plt.ylabel("Price in USD")
plt.xlabel("Size in sq. ft.")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import sys
sys.path.append('/content/misc_files')
from lab_utils_uni import plt_intuition

# %%
def compute_cost(x, y, w, b):
  m = x.shape[0]
  cost_sum = 0
  for i in range(m):
    f_wb = w * x[i] + b
    cost = (f_wb-y[i])**2
    cost_sum = cost_sum + cost
    total_cost = (1/(2*m))*cost_sum
  return total_cost

# %%
x_train = np.array([1.0,2.0])
y_train = np.array([300.0,500.0])

# %%
plt_intuition(x_train, y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %%
from lab_utils_uni import plt_stationary, plt_update_onclick, soup_bowl

plt.close('all')
fig, ax, dyn_items = plt_stationary (x_train, y_train)
updater = plt_update_onclick(fig, ax, x_train, y_train, dyn_items)

# %%
soup_bowl()

# %%
def compute_gradient(x, y, w, b):
  m = x.shape[0]
  dj_dw = 0
  dj_db = 0
  for i in range(m)  :
    f_wb = w * x[i] +b
    dj_dw_i = (f_wb - y[i] * x[i])
    dj_db_i = f_wb - y[i]
    dj_dw += dj_dw_i
    dj_db += dj_db_i
    dj_dw = dj_dw/m
    dj_db = dj_db/m
  return dj_dw, dj_db

# %%
from lab_utils_uni import plt_gradients
plt_gradients (x_train, y_train, compute_cost, compute_gradient)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import math, copy

# %%
def gradient_descent(x, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function):
    w = copy.deepcopy(w_in)
    J_history = []
    p_history = []
    b = b_in
    w = w_in
    for i in range(num_iters):
        dj_dw, dj_db = gradient_function(x, y, w, b)
        b = b - alpha * dj_db
        w = w - alpha * dj_dw
        if i < 10000:
            J_history.append(cost_function(x, y, w, b))
            p_history.append([w,b])
        if i%math.ceil(num_iters/10) == 0:
            print(f"Iteration {i:4}: Cost {J_history[-1]:0.2e} ",
                  f"dj_dw: {dj_dw: 0.3e}, dj_db: {dj_db:0.3e} ",
                  f"w: {w: 0.3e}, b: {b: 0.3e}")
            
    return w, b, J_history, p_history
